# %%
import zipfile
# !unzip /content/digit_svm.zip
# Out:
# Archive:  /content/digit_svm.zip
#   inflating: digit_svm.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/digit_svm.csv")

# %%
y = df["label"]

# %%
x = df.iloc[:,1:]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC
clf = SVC(random_state=0)
clf.fit(x_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9757142857142858

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[795,   0,   1,   1,   1,   3,   2,   0,   3,   0],
#        [  0, 923,   3,   1,   2,   1,   0,   2,   1,   1],
#        [  3,   1, 810,   3,   1,   0,   1,   7,   3,   2],
#        [  0,   2,  10, 853,   0,  12,   0,   2,   5,   1],
#        [  1,   0,   1,   0, 833,   0,   2,   1,   1,  11],
#        [  1,   1,   2,  10,   3, 759,   3,   0,   3,   4],
#        [  4,   1,   0,   0,   1,   2, 813,   0,   1,   0],
#        [  1,   5,   5,   1,   5,   0,   0, 849,   0,   6],
#        [  2,   2,   0,   1,   3,   2,   2,   0, 776,   2],
#        [  4,   0,   0,   4,  13,   2,   0,  13,   3, 785]])

# %%
clf_2 = SVC(kernel="sigmoid",random_state=0)

# %%
clf_2.fit(x_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='sigmoid',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
y_pred_2 = clf_2.predict(x_test)

# %%
accuracy_score(y_test,y_pred_2)
# Out:
# 0.7807142857142857

# %%
confusion_matrix(y_test,y_pred_2)
# Out:
# array([[686,   0,  22,   3,   4,  60,  18,   3,  10,   0],
#        [  0, 894,   5,   7,   0,   5,   1,   4,  18,   0],
#        [ 18,  17, 636,  24,  20,  13,  45,   9,  42,   7],
#        [ 22,  13,  53, 626,   4,  91,  12,  11,  47,   6],
#        [  5,   7,  13,   1, 712,   3,  14,   4,  25,  66],
#        [ 40,  22,  12,  77,  15, 521,  17,   5,  74,   3],
#        [ 18,  13,  60,   1,  18,  19, 678,   0,  15,   0],
#        [ 25,   5,  27,   6,  20,  12,   0, 715,  14,  48],
#        [ 11,  45,  42,  22,  18,  84,   5,   6, 535,  22],
#        [ 15,   0,  13,  12,  98,  28,   0,  68,  35, 555]])

# %%
clf_3 = SVC(kernel="poly",random_state=0)

# %%
clf_3.fit(x_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
y_pred_3=clf_3.predict(x_test)

# %%
accuracy_score(y_test,y_pred_3)
# Out:
# 0.9704761904761905

# %%
confusion_matrix(y_test,y_pred_3)
# Out:
# array([[790,   0,   2,   0,   1,   7,   3,   0,   2,   1],
#        [  0, 924,   3,   0,   2,   1,   1,   2,   1,   0],
#        [  5,   6, 801,   2,   2,   1,   1,   8,   3,   2],
#        [  1,   7,   9, 842,   0,  13,   1,   3,   6,   3],
#        [  2,   1,   0,   0, 833,   0,   2,   1,   2,   9],
#        [  2,   1,   0,   4,   2, 767,   3,   0,   3,   4],
#        [  4,   6,   0,   0,   1,   3, 806,   0,   2,   0],
#        [  1,   6,   2,   2,   5,   0,   0, 850,   0,   6],
#        [  4,   4,   5,   3,   3,   4,   0,   0, 761,   6],
#        [  3,   2,   0,   4,  11,   5,   1,  17,   3, 778]])
